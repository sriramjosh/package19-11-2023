# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we created in first photo  new folder and name named as task in that

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# in that we intilize for task (init.py)and after that in that task   after we opened spider python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we created the file and names as task11 as modilies for writhing the program so we want to create the
# package so we taken named as task in first photo in that we created three new folder

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we opned spider as we opned new file as we saved task11.py in task 1 in task so now  we done save to task22,task 33  we want to create a package

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# now what we done in task 11 in spider we should write a program so i writern a place,name, study,place

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# now we written a program using a def function we saved as task11.py

# %% [markdown]
# ![Screenshot%202023-11-19%20120834.png](attachment:Screenshot%202023-11-19%20120834.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# now we named as print(main),print(hello),print(place),print(study),print(now). tas31 new file same code given the exution

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# now we created modiles now we want to create package

# %% [markdown]
# now we taken new file we named as homework

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# now  main package that import sys,od , next systempath next systempath.we are using (insert(0,c:\\)windowsc),now we are opning(task)by using (import task),now from task calling task1 import11((task.task1 import11) now we calling (task11.great),(task11.place),(task.study)

# %% [markdown]
# ![image.png](attachment:image.png)
